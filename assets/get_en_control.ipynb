# %%
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv("")

json_data = data.to_json(orient='records')


with open('data_control_dk.json', 'w') as json_file:
    json_file.write(json_data)
